# %%
import random

def random_black_red():
    #creating a function to randomly generate black or red
    return random.choice(['red', 'black'])

def roulette_number():
    return random.randint(0,36)

Money = int(input("how much do you want to start your balance with? "))

while True:

    play_option = input("Would you like to play Roulette?").lower()

    if play_option != "yes":
        break

    choice = input("Would you like to pick inside or outside? ")

    if choice.lower() == "outside":
        choice_2 = input("color, even or odd, columns? ")
        if choice_2.lower() == "color":
            correct_color = random_black_red()
            color_choice = input("enter your choice, Red or Black: ")
            while True:
                bet = input("enter your bet: ")

                if not bet.isdigit(): 
                    print("Invalid")
                if int(bet) <= Money and int(bet) > 0:
                    break

                print("Not Allowed. Please bet a sufficient amount")

            print("The wheel landed on " + correct_color)

            bet = int(bet)

            if color_choice.lower() == correct_color:
                Money += bet
                print("You won " + str(bet) + " you have a balance of " + str(Money))
            else:
                Money -= bet
                print("You a lwoserrr " + str(bet))
                print('Current balance is ' + str(Money))
    else:
        chosen_numbers = []
        bet_list = []

        while True:
            
            choice_2 = input("What would you like to bet on? (if multiple numbers, please enter multiple number separated by commas.) Type finished when all choices are made: ")
            
            if choice_2.lower() == "finished":
                break

            if choice_2.isdigit() and 0 <= int(choice_2) <= 36:
                chosen_numbers.append(int(choice_2))
                while True:
                    bet = input("Enter your bet for each number: ")
                    if not bet.isdigit(): 
                        print("Invalid")
                    if int(bet) <= Money and int(bet) > 0:
                        bet_list.append(int(bet))
                        break

                    print("Not Allowed. Please bet a sufficient amount")
            else:
                print("Must be numbers between 0 and 36")
# Out:
# The wheel landed on red
# You won 10 you have a balance of110
# Must be numbers between 0 and 36
# Must be numbers between 0 and 36
# Must be numbers between 0 and 36
